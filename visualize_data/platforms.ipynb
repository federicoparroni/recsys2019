# %%
import sys
import os
os.chdir("../")

import pandas as pd
import data

from tqdm import tqdm

# %matplotlib notebook

# %%
train_df = data.train_df('full')

# %%
train_df.head(10)
# Out:
#         user_id     session_id   timestamp  step             action_type  \
# 0  008UN2RY0DMY  cd10940538005  1541031243     1  search for destination
# 1  008UN2RY0DMY  cd10940538005  1541031463     2    change of sort order
# 2  008UN2RY0DMY  cd10940538005  1541031473     3    change of sort order
# 3  008UN2RY0DMY  cd10940538005  1541031473     4        filter selection
# 4  008UN2RY0DMY  cd10940538005  1541031550     5  interaction item image
# 5  008UN2RY0DMY  cd10940538005  1541031550     6  interaction item image
# 6  008UN2RY0DMY  cd10940538005  1541031560     7  interaction item image
# 7  008UN2RY0DMY  cd10940538005  1541031560     8  interaction item image
# 8  008UN2RY0DMY  cd10940538005  1541031570     9  interaction item image
# 9  008UN2RY0DMY  cd10940538005  1541031570    10  interaction item image
#
#                   reference platform            city   device  \
# 0            Rochester, USA       US  Rochester, USA  desktop
# ...

# %% [markdown]
# ## Platforms distribution

# %%
session_groups = train_df[['session_id','timestamp','user_id','platform']].groupby('session_id').first()
session_groups.head(20)
# Out:
#                 timestamp       user_id platform
# session_id
# 00000510f1adc  1541064087  WT30CXPIG450       IN
# 00003f3b20954  1541097696  CITFOTN2IT5P       ES
# 000056cd97ce2  1541483846  0TBXPQCK401O       MY
# 000066611146f  1541332305  XRIOQ0R1CHLT       BE
# 00008c1f39c46  1541302205  MSD74FLNTFNE       JP
# 0000be39860d7  1541102752  X931R6LTG2RE       US
# 0000c0fb51e11  1541240881  SMEARDEG4VRK       MY
# 0000c8490c155  1541349379  C7G6RE64H25Q       MX
# 0000d4284ff9b  1541269653  GF1RRZKHM34J       BR
# 0000de36576fe  1541155776  J87GWRE76LO2       CH
# 0000fd3bf7543  1541042615  R1TQCU5WC8IQ       JP
# 00011005327e1  1541539680  M7K6U5Q4ZNBM       US
# 000130c2690b4  1541224805  0G4P8FP6ORNN       IN
# 000138ab4f789  1541444149  WDBP226XSN9E       US
# 00019322edd5d  1541235460  JFZVBNZUIFR2       GR
# 000195d02a8a9  1541382865  Z0TZ5TYJHJIL       AR
# 00019f78d2c36  1541303014  5XUW42OSAUU6       US
# 0001acb13ccd1  1541188880  2LVZYAWP3XD7       AA
# ...

# %%
platforms_groups = session_groups[['platform','user_id']].groupby('platform').count()

# %%
platforms_groups
# Out:
#           user_id
# platform
# AA           5401
# AE           2383
# AR          23964
# AT           5731
# AU          31696
# BE           6044
# BG           4552
# BR         110380
# CA          25342
# CH           6891
# CL           3849
# CN             94
# CO          10818
# CZ           3691
# DE          54877
# DK           4687
# EC           2355
# ES          30165
# FI           5359
# FR          23348
# GR           6260
# HK           6826
# HR           1393
# HU           4564
# ID           2225
# IE           8665
# IL           6961
# IN          46156
# IT          30852
# JP          63188
# KR           4772
# MX          38779
# MY          24323
# NL          15437
# NO           3961
# NZ           7533
# PE           3149
# PH          10699
# PL          14281
# PT           5548
# RO           5497
# RS           2207
# RU          20208
# SE           8442
# SG           4874
# SI            643
# SK           1835
# TH           6412
# ...

# %%
platforms_groups.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="976">
