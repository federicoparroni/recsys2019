# %%
import sys
import os
os.chdir("../")

import pandas as pd
import data

# %matplotlib notebook

# %%
train_df = data.train_df('full')

# %%
train_df.head(10)
# Out:
#         user_id     session_id   timestamp  step             action_type  \
# 0  008UN2RY0DMY  cd10940538005  1541031243     1  search for destination
# 1  008UN2RY0DMY  cd10940538005  1541031463     2    change of sort order
# 2  008UN2RY0DMY  cd10940538005  1541031473     3    change of sort order
# 3  008UN2RY0DMY  cd10940538005  1541031473     4        filter selection
# 4  008UN2RY0DMY  cd10940538005  1541031550     5  interaction item image
# 5  008UN2RY0DMY  cd10940538005  1541031550     6  interaction item image
# 6  008UN2RY0DMY  cd10940538005  1541031560     7  interaction item image
# 7  008UN2RY0DMY  cd10940538005  1541031560     8  interaction item image
# 8  008UN2RY0DMY  cd10940538005  1541031570     9  interaction item image
# 9  008UN2RY0DMY  cd10940538005  1541031570    10  interaction item image
#
#                   reference platform            city   device  \
# 0            Rochester, USA       US  Rochester, USA  desktop
# ...

# %% [markdown]
# ## Devices distribution

# %%
session_groups = train_df[['session_id','device']].reset_index().groupby('session_id').first()
session_groups.head(20)
# Out:
#                   index   device
# session_id
# 00000510f1adc   3072638  desktop
# 00003f3b20954   7205321   mobile
# 000056cd97ce2  11118794  desktop
# 000066611146f   1225121  desktop
# 00008c1f39c46   2478061   mobile
# 0000be39860d7  11225025  desktop
# 0000c0fb51e11  14763166   mobile
# 0000c8490c155   5127097   mobile
# 0000d4284ff9b  10863680   mobile
# 0000de36576fe   8651304  desktop
# 0000fd3bf7543   7052192   mobile
# 00011005327e1  15442918   tablet
# 000130c2690b4  12758406   mobile
# 000138ab4f789  12563998  desktop
# 00019322edd5d   6153057  desktop
# 000195d02a8a9   5714733   mobile
# 00019f78d2c36   8444187  desktop
# 0001acb13ccd1  13066659  desktop
# 0001b9615355c   2009817   mobile
# 0001c758d8d1f  12394857   mobile

# %%
devices_groups = session_groups.groupby('device').count()
devices_groups
# Out:
#           index
# device
# desktop  303713
# mobile   534555
# tablet    72415

# %%
len(session_groups)
# Out:
# 910683

# %%
devices_groups.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">
